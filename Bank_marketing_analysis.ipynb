# %% [markdown]
# ## Importing all necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.inspection import permutation_importance
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay, roc_curve
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.svm import SVC
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.metrics import precision_recall_curve

# %%
df = pd.read_csv('data/bank-additional-full.csv', sep = ';')

# %% [markdown]
# ## Exploratory Data Analysis (EDA)¶
#
# The data is from a bank marketing campaign.
# Following is the description of every column of the dataframe
#
# ```
# Input variables:
# # bank client data:
# 1 - age (numeric)
# 2 - job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# 3 - marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# 4 - education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# 5 - default: has credit in default? (categorical: 'no','yes','unknown')
# 6 - housing: has housing loan? (categorical: 'no','yes','unknown')
# 7 - loan: has personal loan? (categorical: 'no','yes','unknown')
# # related with the last contact of the current campaign:
# 8 - contact: contact communication type (categorical: 'cellular','telephone')
# 9 - month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# 10 - day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# 11 - duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
# # other attributes:
# 12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 14 - previous: number of contacts performed before this campaign and for this client (numeric)
# 15 - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
# # social and economic context attributes
# 16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
# 17 - cons.price.idx: consumer price index - monthly indicator (numeric)
# 18 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# 19 - euribor3m: euribor 3 month rate - daily indicator (numeric)
# 20 - nr.employed: number of employees - quarterly indicator (numeric)
#
# Output variable (desired target):
# 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')
# ```

# %%
df.sample(5)
# Out:
#        age          job  marital            education default housing loan  \
# 31717   31   technician  married  professional.course      no     yes   no
# 36731   45     services   single              unknown      no      no   no
# 4315    21       admin.   single             basic.9y      no     yes  yes
# 31646   33     services  married          high.school      no     yes   no
# 39960   32  blue-collar   single          high.school      no      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 31717   cellular   may         thu  ...         1    999         0
# 36731   cellular   jun         mon  ...         2    999         0
# 4315   telephone   may         tue  ...         1    999         0
# 31646   cellular   may         thu  ...         1    999         2
# 39960   cellular   jun         mon  ...         1      2         2
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 31717  nonexistent         -1.8          92.893          -46.2      1.327
# 36731  nonexistent         -2.9          92.963          -40.8      1.281
# 4315   nonexistent          1.1          93.994          -36.4      4.856
# 31646      failure         -1.8          92.893          -46.2      1.327
# 39960      success         -1.7          94.055          -39.8      0.754
#
#        nr.employed    y
# 31717       5099.1   no
# 36731       5076.2   no
# 4315        5191.0   no
# 31646       5099.1   no
# 39960       4991.6  yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %% [markdown]
# #### What is the distribution of the outcome feature?
#
# The data is imbalanced.
# Keep this in mind when interpreting the results

# %%
sns.countplot(data=df,x='y')
plt.show()

# %% [markdown]
# #### Are there any correlation

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# #### What are the stats of the numerical features?

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Data cleaning
#
# #### Are there any missing data?
#
# It looks like there are no missing data

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# #### Handleling duplicate values

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Feature engineering
#
# #### Transformation of categorical features with low cardinality
#
# The One hot encoder will be used for high cardinality categorical features

# %%
le = LabelEncoder()
df.marital = le.fit_transform(df.marital)
df.housing = le.fit_transform(df.housing)
df.y = le.fit_transform(df.y)
df.loan = le.fit_transform(df.loan)
df.default = le.fit_transform(df.default)
df.contact = le.fit_transform(df.contact)

# %% [markdown]
# #### How does the correlation looks like now?
#
# There is a good correlation of the outcome and the call duration

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# #### Creation of a pipeline to take care of categorical features with high cardinality and scaler for numerical feautures

# %%
ct = make_column_transformer(
     (StandardScaler(), ['age','duration','campaign']),
     (OneHotEncoder(), ['job','education','month','day_of_week','poutcome']))

# %% [markdown]
# #### Data split

# %%
X = df.drop('y', axis=1)
y = df['y']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42, test_size = .33)

# %% [markdown]
# ### Model training
#
# #### Model creation

# %%
lr_pipe = Pipeline([('ct', ct), ('model', LogisticRegression(max_iter = 800))])
dt_pipe = Pipeline([('ct', ct), ('model', DecisionTreeClassifier())])
knn_pipe = Pipeline([('ct', ct), ('model', KNeighborsClassifier())])
svc_pipe = Pipeline([('ct', ct), ('model', SVC())])

# %% [markdown]
# #### Best model search

# %%
lr_params = {'model__C':[0.1,0.5,1,2],'model__penalty':['l1','l2']
             , 'model__solver':['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']}
dt_params = {'model__max_depth':[5,6,7,8,9,10], 'model__criterion':['gini', 'entropy', 'log_loss']}
knn_params = {'model__n_neighbors':[5,6,7,8,9,10]}
svc_params = {'model__kernel':['linear','poly','rbf','sigmoid', 'precomputed']}

# %%
lr_search = RandomizedSearchCV(lr_pipe, lr_params).fit(X_train,y_train)
dt_search = RandomizedSearchCV(dt_pipe, dt_params).fit(X_train,y_train)
knn_search = RandomizedSearchCV(knn_pipe, knn_params).fit(X_train,y_train)
svc_search = RandomizedSearchCV(svc_pipe, svc_params).fit(X_train,y_train)

# %% [markdown]
# #### Models results

# %%
#Test scores
test_score =[]
test_score.append(lr_search.score(X_test, y_test))
test_score.append(dt_search.score(X_test, y_test))
test_score.append(knn_search.score(X_test, y_test))
test_score.append(svc_search.score(X_test, y_test))
#Train scores
train_score =[]
train_score.append(lr_search.best_score_)
train_score.append(dt_search.best_score_)
train_score.append(knn_search.best_score_)
train_score.append(svc_search.best_score_)
#Relative time
time_ =[]
time_.append(lr_search.cv_results_['mean_fit_time'].sum())
time_.append(dt_search.cv_results_['mean_fit_time'].sum())
time_.append(knn_search.cv_results_['mean_fit_time'].sum())
time_.append(svc_search.cv_results_['mean_fit_time'].sum())
#precision score
precision =[]
precision.append(precision_score(y_test, lr_search.predict(X_test)))
precision.append(precision_score(y_test, dt_search.predict(X_test)))
precision.append(precision_score(y_test, knn_search.predict(X_test)))
precision.append(precision_score(y_test, svc_search.predict(X_test)))
#recall score
recall =[]
recall.append(recall_score(y_test, lr_search.predict(X_test)))
recall.append(recall_score(y_test, dt_search.predict(X_test)))
recall.append(recall_score(y_test, knn_search.predict(X_test)))
recall.append(recall_score(y_test, svc_search.predict(X_test)))
#results data frame
d={'Classifier': ['Logistic Regression','Decision Tree', 'KNN', 'SVC'], 'time': time_
   ,'Training score':train_score,'Testing score':test_score,'precision':precision,'recall':recall}
dfp = pd.DataFrame(data = d)
dfp
# Out:
#             Classifier       time  Training score  Testing score  precision  \
# 0  Logistic Regression   8.464971        0.906550       0.903819   0.645278
# 1        Decision Tree   1.865858        0.908363       0.904334   0.636766
# 2                  KNN   0.325074        0.899844       0.898962   0.626822
# 3                  SVC  39.048421        0.908761       0.905659   0.659064
#
#      recall
# 0  0.344538
# 1  0.371687
# 2  0.277957
# 3  0.354880

# %% [markdown]
# The precision and the recall are low

# %% [markdown]
# ### What happens is the data is balanced?

# %%
#resampling the data
df_s = df.sample(frac=1, random_state=42)
df_t = df_s.loc[df_s['y'] == 1]
df_f = df_s.loc[df_s['y'] == False][:df_t.shape[0]]
#Concat
normal_distributed_df = pd.concat([df_t, df_f])
#sample
new_df = normal_distributed_df.sample(frac=1, random_state=42)

# %% [markdown]
# ### New data split

# %%
X = new_df.drop('y', axis=1)
y = new_df['y']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42, test_size = .1)

# %% [markdown]
# ### Model training

# %%
lr_search = RandomizedSearchCV(lr_pipe, lr_params).fit(X_train,y_train)
dt_search = RandomizedSearchCV(dt_pipe, dt_params).fit(X_train,y_train)
knn_search = RandomizedSearchCV(knn_pipe, knn_params).fit(X_train,y_train)
svc_search = RandomizedSearchCV(svc_pipe, svc_params).fit(X_train,y_train)

# %% [markdown]
# ### Model results

# %%
#Test scores
test_score =[]
test_score.append(lr_search.score(X_test, y_test))
test_score.append(dt_search.score(X_test, y_test))
test_score.append(knn_search.score(X_test, y_test))
test_score.append(svc_search.score(X_test, y_test))
#Train scores
train_score =[]
train_score.append(lr_search.best_score_)
train_score.append(dt_search.best_score_)
train_score.append(knn_search.best_score_)
train_score.append(svc_search.best_score_)
#Relative time
time_ =[]
time_.append(lr_search.cv_results_['mean_fit_time'].sum())
time_.append(dt_search.cv_results_['mean_fit_time'].sum())
time_.append(knn_search.cv_results_['mean_fit_time'].sum())
time_.append(svc_search.cv_results_['mean_fit_time'].sum())
#precision score
precision =[]
precision.append(precision_score(y_test, lr_search.predict(X_test)))
precision.append(precision_score(y_test, dt_search.predict(X_test)))
precision.append(precision_score(y_test, knn_search.predict(X_test)))
precision.append(precision_score(y_test, svc_search.predict(X_test)))
#recall score
recall =[]
recall.append(recall_score(y_test, lr_search.predict(X_test)))
recall.append(recall_score(y_test, dt_search.predict(X_test)))
recall.append(recall_score(y_test, knn_search.predict(X_test)))
recall.append(recall_score(y_test, svc_search.predict(X_test)))
#results data frame
d={'Classifier': ['Logistic Regression','Decision Tree', 'KNN', 'SVC'], 'calculation time': time_
   ,'Training score':train_score,'Testing score':test_score,'precision':precision,'recall':recall}
dfp = pd.DataFrame(data = d)
dfp
# Out:
#             Classifier  calculation time  Training score  Testing score  \
# 0  Logistic Regression          2.091838        0.822275       0.820043
# 1        Decision Tree          0.690712        0.821198       0.815733
# 2                  KNN          0.131338        0.806228       0.786638
# 3                  SVC          6.041437        0.846826       0.836207
#
#    precision    recall
# 0   0.847458  0.770925
# 1   0.813747  0.808370
# 2   0.816832  0.726872
# 3   0.829694  0.837004

# %% [markdown]
# The results look better now and the SVC model is the better

# %% [markdown]
# ### Do we need all the features for this study?
#
# #### Features importance analysis

# %%
r = permutation_importance(svc_search.best_estimator_, X, y,
                            n_repeats=5,
                            random_state=42)
for i in r.importances_mean.argsort()[::-1]:
    print(f"{X.columns[i]:<15}"
            f"{r.importances_mean[i]:.3f}"
            f" +/- {r.importances_std[i]:.3f}")
# Out:
# duration       0.223 +/- 0.005
# month          0.083 +/- 0.001
# poutcome       0.065 +/- 0.002
# age            0.025 +/- 0.001
# job            0.013 +/- 0.001
# education      0.012 +/- 0.001
# campaign       0.010 +/- 0.001
# day_of_week    0.010 +/- 0.001
# pdays          0.000 +/- 0.000
# previous       0.000 +/- 0.000
# euribor3m      0.000 +/- 0.000
# emp.var.rate   0.000 +/- 0.000
# contact        0.000 +/- 0.000
# loan           0.000 +/- 0.000
# housing        0.000 +/- 0.000
# default        0.000 +/- 0.000
# cons.price.idx 0.000 +/- 0.000
# marital        0.000 +/- 0.000
# cons.conf.idx  0.000 +/- 0.000
# nr.employed    0.000 +/- 0.000

# %% [markdown]
# The duration is the most important feature, pass 500s, most people subscribe a term deposit

# %%
sns.displot(data=new_df, x="duration", hue="y", kind="kde")
plt.show()

# %% [markdown]
# What about the age?
# Below 30 and above 58 more people subscribe a term deposit compared to the ages in between.

# %%
ax = sns.displot(data=new_df, x="age", hue="y", kind="kde")
plt.show()

# %% [markdown]
# The months of april, october, march, september and december are more favorable to a term deposit

# %%
ax = sns.histplot(data=new_df, x="month", hue="y",stat="percent")
ax.set_title('Acceptance per month')
plt.show()

# %% [markdown]
# If the previous autcome was a success, the chances are high to have another success

# %%
ax = sns.histplot(data=new_df, x="poutcome", hue="y",stat="percent")
ax.set_title('Acceptance per previous outcome')
plt.show()

# %% [markdown]
# Most people with an university degree will subscribe a term deposit

# %%
ax = sns.histplot(data=new_df, x="education", hue="y",stat="percent")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_title('Acceptance per education')
plt.show()

# %% [markdown]
# The worst day of the week to call are Monday and Friday

# %%
ax = sns.histplot(data=new_df, x="day_of_week", hue="y",stat="percent")
ax.set_title('Acceptance per day of the week')
plt.show()

# %% [markdown]
# Retired, students and admin are more likely to subscribe a term deposit

# %%
ax = sns.histplot(data=new_df, x="job", hue="y",stat="percent")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_title('Acceptance per job title')
plt.show()

# %% [markdown]
# ### Confusion matrix of the best model

# %%
svc_pipe = Pipeline([('ct', ct), ('model', SVC(kernel='rbf',probability=True))]).fit(X_train,y_train)

# %%
predictions = svc_pipe.predict(X_test)
cm = confusion_matrix(y_test, predictions, labels=lr_search.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=lr_search.classes_)
disp.plot()

plt.show()

# %% [markdown]
# ### Precision and recall tradeoff

# %%
y_scores = svc_pipe.predict_proba(X_test)

if y_scores.ndim == 2:
    y_scores = y_scores[:, 1]
    
precisions, recalls, threshold = precision_recall_curve(y_test, y_scores,)

def precision_recall_curve_(precisions, recalls, thresholds):
    fig, ax = plt.subplots(figsize=(12,8))
    plt.plot(thresholds, precisions[:-1], "g--", label="Precisions")
    plt.plot(thresholds, recalls[:-1], "#1e81b0", label="Recalls")
    plt.title("Precision and Recall Tradeoff", fontsize=18)
    plt.ylabel("Level of Precision and Recall", fontsize=16)
    plt.xlabel("Thresholds", fontsize=16)
    plt.legend(loc="best", fontsize=14)
    plt.xlim([0, 1.])
    plt.ylim([0, 1])
    plt.axvline(x=0.506, linewidth=3, color="#0B3861")
    plt.annotate('Best Precision and \n Recall Balance \n is at 0.5 \n threshold ', xy=(0.506, 0.83), xytext=(60, -10),
             textcoords="offset points",
            arrowprops=dict(facecolor='black', shrink=0.5),
                fontsize=12, 
                color='k')
    plt.show()
    
precision_recall_curve_(precisions, recalls,threshold)

# %% [markdown]
# ### Conclusions
#
# The more time you spend on the phone, the more likely the person will subscribe. Call when people are available to talk. The months of april, october, march, september and december are more favorable. Do not call on Monday or Friday. Retiries, admin and students are more likely to subscribe. An university degree is a good indicator of acceptance.
